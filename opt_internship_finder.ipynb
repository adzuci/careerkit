# %% [markdown]
# # OPT-Friendly CS Internship Finder (jobspy + Python)
#
# This notebook scrapes CS-related internship postings from job sites using **jobspy**
# and filters for roles that appear **OPT-friendly** based on keyword heuristics.
#
# > ⚠️ **Disclaimer**
# > - This does **not** guarantee OPT eligibility or visa sponsorship.
# > - Always verify details on the company's careers page and with recruiters.
# > - Scraping may be subject to each site's Terms of Service; use responsibly.

# %%
# !pip install -U python-jobspy
# Out:
# Collecting python-jobspy
#   Downloading python_jobspy-1.1.82-py3-none-any.whl.metadata (10 kB)
# Collecting NUMPY==1.26.3 (from python-jobspy)
#   Downloading numpy-1.26.3-cp312-cp312-macosx_10_9_x86_64.whl.metadata (61 kB)
# Collecting beautifulsoup4<5.0.0,>=4.12.2 (from python-jobspy)
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting markdownify<0.14.0,>=0.13.1 (from python-jobspy)
#   Downloading markdownify-0.13.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting pandas<3.0.0,>=2.1.0 (from python-jobspy)
#   Downloading pandas-2.3.3-cp312-cp312-macosx_10_13_x86_64.whl.metadata (91 kB)
# Collecting pydantic<3.0.0,>=2.3.0 (from python-jobspy)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting regex<2025.0.0,>=2024.4.28 (from python-jobspy)
#   Downloading regex-2024.11.6-cp312-cp312-macosx_10_13_x86_64.whl.metadata (40 kB)
# Collecting requests<3.0.0,>=2.31.0 (from python-jobspy)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting tls-client<2.0.0,>=1.0.1 (from python-jobspy)
#   Downloading tls_client-1.0.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4<5.0.0,>=4.12.2->python-jobspy)
#   Downloading soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4<5.0.0,>=4.12.2->python-jobspy)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: six<2,>=1.15 in ./.venv/lib/python3.12/site-packages (from markdownify<0.14.0,>=0.13.1->python-jobspy) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.0->python-jobspy) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas<3.0.0,>=2.1.0->python-jobspy)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3.0.0,>=2.1.0->python-jobspy)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.3.0->python-jobspy)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.3.0->python-jobspy)
#   Downloading pydantic_core-2.41.5-cp312-cp312-macosx_10_12_x86_64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.3.0->python-jobspy)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.31.0->python-jobspy)
#   Downloading charset_normalizer-3.4.4-cp312-cp312-macosx_10_13_universal2.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.31.0->python-jobspy)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.31.0->python-jobspy)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.31.0->python-jobspy)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Downloading python_jobspy-1.1.82-py3-none-any.whl (52 kB)
# Downloading numpy-1.26.3-cp312-cp312-macosx_10_9_x86_64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 43.2 MB/s  0:00:003.1 MB/s eta 0:00:01:01
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading markdownify-0.13.1-py3-none-any.whl (10 kB)
# Downloading pandas-2.3.3-cp312-cp312-macosx_10_13_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 60.6 MB/s  0:00:00
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-macosx_10_12_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 47.1 MB/s  0:00:00
# Downloading regex-2024.11.6-cp312-cp312-macosx_10_13_x86_64.whl (288 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp312-cp312-macosx_10_13_universal2.whl (208 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading tls_client-1.0.1-py3-none-any.whl (41.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 MB 40.9 MB/s  0:00:010.5 MB/s eta 0:00:01:01
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading soupsieve-2.8-py3-none-any.whl (36 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: tls-client, pytz, urllib3, tzdata, typing-extensions, soupsieve, regex, NUMPY, idna, charset_normalizer, certifi, annotated-types, typing-inspection, requests, pydantic-core, pandas, beautifulsoup4, pydantic, markdownify, python-jobspy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/20 [python-jobspy]19/20 [python-jobspy]ons]
# Successfully installed NUMPY-1.26.3 annotated-types-0.7.0 beautifulsoup4-4.14.3 certifi-2025.11.12 charset_normalizer-3.4.4 idna-3.11 markdownify-0.13.1 pandas-2.3.3 pydantic-2.12.5 pydantic-core-2.41.5 python-jobspy-1.1.82 pytz-2025.2 regex-2024.11.6 requests-2.32.5 soupsieve-2.8 tls-client-1.0.1 typing-extensions-4.15.0 typing-inspection-0.4.2 tzdata-2025.2 urllib3-2.5.0

# %%
import csv
from jobspy import scrape_jobs

jobs = scrape_jobs(
    site_name=["indeed", "linkedin", "google"], #"zip_recruiter", "glassdoor", "bayt", "naukri", "bdjobs"
    search_term="\"software engineering intern\" -sales",
    google_search_term="software internship jobs in the US since last week",
    location="USA",
    results_wanted=20,
    hours_old=100,
    country_indeed='USA',

    # linkedin_fetch_description=True # gets more info such as description, direct job url (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
)
print(f"Found {len(jobs)} jobs")
print(jobs.head())
jobs.to_csv("jobs.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel
# Out:
# 2025-12-03 07:12:38,526 - INFO - JobSpy:Linkedin - finished scraping
# Found 40 jobs
#                     id    site  \
# 0  in-5102d0c18675267d  indeed
# 1  in-2367541993d49d2f  indeed
# 2  in-b8f5bf834d5a63ac  indeed
# 3  in-1870b2ed5917295a  indeed
# 4  in-9c53e8847318341d  indeed
#
#                                              job_url  \
# 0  https://www.indeed.com/viewjob?jk=5102d0c18675...
# 1  https://www.indeed.com/viewjob?jk=2367541993d4...
# 2  https://www.indeed.com/viewjob?jk=b8f5bf834d5a...
# 3  https://www.indeed.com/viewjob?jk=1870b2ed5917...
# 4  https://www.indeed.com/viewjob?jk=9c53e8847318...
#
#                                       job_url_direct  \
# 0  https://jobs.disneycareers.com/job/orlando/sof...
# 1  https://jobs.disneycareers.com/job/lake-buena-...
# 2  https://click.appcast.io/t/0F9M0CFwFVdSHnyd6hJ...
# 3  https://wisk.wd108.myworkdayjobs.com/en-US/Wis...
# 4  https://jobs.ashbyhq.com/telus-digital/4486bd5...
#
#                                             title                  company  \
# 0        Software Engineering Intern, Summer 2026  The Walt Disney Company
# 1        Software Engineering Intern, Summer 2026  The Walt Disney Company
# 2                   Software Engineering - Intern          Lockheed Martin
# 3            Avionics Software Engineering Intern                Wisk Aero
# 4  Software Engineering Intern (US) - Summer 2026                      NaN
#
#                    location date_posted                        job_type  \
# 0           Orlando, FL, US  2025-12-03                      internship
# 1  Lake Buena Vista, FL, US  2025-12-03                      internship
# 2  Colorado Springs, CO, US  2025-12-02  parttime, fulltime, internship
# 3     Mountain View, CA, US  2025-12-02                        fulltime
# 4            Durham, NC, US  2025-12-02                      internship
#
#   salary_source  ...                                  company_addresses  \
# 0           NaN  ...  500 South Buena Vista Street,\r\nBurbank, Cali...
# 1           NaN  ...  500 South Buena Vista Street,\r\nBurbank, Cali...
# 2           NaN  ...                                       Bethesda, MD
# 3           NaN  ...                                                NaN
# 4           NaN  ...                                                NaN
#
#    company_num_employees       company_revenue  \
# 0                10,000+  more than $10B (USD)
# 1                10,000+  more than $10B (USD)
# 2                10,000+  more than $10B (USD)
# 3                    NaN                   NaN
# 4                    NaN                   NaN
#
#                                  company_description  skills experience_range  \
# 0  Synonymous with quality entertainment and cutt...    None             None
# 1  Synonymous with quality entertainment and cutt...    None             None
# 2  Lockheed Martin Canada: #1 Defence Company in ...    None             None
# 3                                                NaN    None             None
# 4                                                NaN    None             None
#
#   company_rating company_reviews_count vacancy_count work_from_home_type
# 0           None                  None          None                None
# 1           None                  None          None                None
# 2           None                  None          None                None
# 3           None                  None          None                None
# 4           None                  None          None                None
#
# [5 rows x 34 columns]

# %%
import pandas as pd
from jobspy import scrape_jobs

def contains_any(text: str, keywords: list[str]) -> bool:
    """Return True if any keyword appears in the given text (case-insensitive)."""
    if text is None:
        return False
    text = text.lower()
    return any(k in text for k in keywords)

def score_text(text: str, good_keywords: list[str], bad_keywords: list[str]) -> int:
    """Compute a simple OPT-friendliness score: (# good hits) - (# bad hits)."""
    if text is None:
        text = ""
    text = text.lower()
    score = 0
    for k in good_keywords:
        score += text.count(k)
    for k in bad_keywords:
        score -= text.count(k)
    return score

# %%
# === Search configuration ===

SEARCH_TERMS = [
    "computer science intern",
    "software engineer intern",
    "software developer intern",
    "data science intern",
]

# jobspy-supported sites; you can add/remove depending on what works for you
SITES = [
    "indeed",
    "linkedin",
    # "zip_recruiter",
    # "glassdoor",
]

LOCATION = "United States"  # e.g. "United States", "Remote", "Boston, MA"
RESULTS_PER_SITE = 150       # number of results per site per search term
HOURS_OLD = 168              # limit to last 7 days (168 hours)

# === Keyword heuristics for OPT friendliness ===

GOOD_KEYWORDS = [
    "opt",
    "cpt",
    "stem opt",
    "f1",
    "f-1",
    "visa sponsorship",
    "sponsorship available",
    "sponsor visas",
    "h-1b",
    "h1b",
    "international students",
]

BAD_KEYWORDS = [
    "us citizens only",
    "u.s. citizens only",
    "must be a us citizen",
    "citizen only",
    "no sponsorship",
    "cannot sponsor",
    "unable to sponsor",
    "not provide sponsorship",
    "gc or citizen only",
    "green card or citizen only",
]

print("Configuration loaded.")
# Out:
# Configuration loaded.

# %%
all_jobs = []

for site in SITES:
    for term in SEARCH_TERMS:
        print(f"Scraping {site} for '{term}' in {LOCATION} (last {HOURS_OLD} hours)...")
        try:
            jobs_df = scrape_jobs(
                site_name=site,
                search_term=term,
                location=LOCATION,
                results_wanted=RESULTS_PER_SITE,
                hours_old=HOURS_OLD,
                country_indeed="USA",  # relevant for Indeed
            )
            jobs_df["site"] = site
            jobs_df["search_term"] = term
            all_jobs.append(jobs_df)
            print(f"  -> Retrieved {len(jobs_df)} results.")
        except Exception as e:
            print(f"  !! Error scraping {site} for '{term}': {e}")

if not all_jobs:
    raise RuntimeError("No jobs retrieved. Try changing sites, search terms, or HOURS_OLD.")

raw_df = pd.concat(all_jobs, ignore_index=True)
print(f"\nTotal raw jobs collected: {len(raw_df)}")

raw_df.head()
# Out:
# Scraping indeed for 'computer science intern' in United States (last 168 hours)...
#   -> Retrieved 150 results.
# Scraping indeed for 'software engineer intern' in United States (last 168 hours)...
#   -> Retrieved 150 results.
# Scraping indeed for 'software developer intern' in United States (last 168 hours)...
#   -> Retrieved 90 results.
# Scraping indeed for 'data science intern' in United States (last 168 hours)...
#   -> Retrieved 150 results.
# Scraping linkedin for 'computer science intern' in United States (last 168 hours)...
#   -> Retrieved 140 results.
# Scraping linkedin for 'software engineer intern' in United States (last 168 hours)...
#   -> Retrieved 130 results.
# Scraping linkedin for 'software developer intern' in United States (last 168 hours)...
#   -> Retrieved 120 results.
# Scraping linkedin for 'data science intern' in United States (last 168 hours)...
#   -> Retrieved 140 results.
#
# Total raw jobs collected: 1070
# /var/folders/px/lf9z17f12td3nckm6nvv2w380000gn/T/ipykernel_20362/3856432797.py:25: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   raw_df = pd.concat(all_jobs, ignore_index=True)
#                     id    site  \
# 0  in-e59eb8cccdc25689  indeed
# 1  in-6c67e32eed5ed00e  indeed
# 2  in-5102d0c18675267d  indeed
# 3  in-2367541993d49d2f  indeed
# 4  in-ed9df620ea0f87bc  indeed
#
#                                              job_url  \
# 0  https://www.indeed.com/viewjob?jk=e59eb8cccdc2...
# 1  https://www.indeed.com/viewjob?jk=6c67e32eed5e...
# 2  https://www.indeed.com/viewjob?jk=5102d0c18675...
# 3  https://www.indeed.com/viewjob?jk=2367541993d4...
# 4  https://www.indeed.com/viewjob?jk=ed9df620ea0f...
#
#                                       job_url_direct  \
# 0  https://vhr-epri.wd1.myworkdayjobs.com/en-US/e...
# 1  https://jobs.disneycareers.com/job/bay-lake/da...
# 2  https://jobs.disneycareers.com/job/orlando/sof...
# 3  https://jobs.disneycareers.com/job/lake-buena-...
# 4  https://careers.hfsinclair.com/job/Dallas-Inte...
#
#                                                title  \
# 0  Energy Supply Student Internship: Fusion Stude...
# 1                   Data Product Intern, Summer 2026
# 2           Software Engineering Intern, Summer 2026
# 3           Software Engineering Intern, Summer 2026
# 4                  Intern, Internal Audit Technology
#
#                              company                  location date_posted  \
# 0  Electric Power Research Institute         Charlotte, NC, US  2025-12-03
# 1            The Walt Disney Company          Bay Lake, FL, US  2025-12-03
# 2            The Walt Disney Company           Orlando, FL, US  2025-12-03
# 3            The Walt Disney Company  Lake Buena Vista, FL, US  2025-12-03
# 4                        Hf Sinclair            Dallas, TX, US  2025-12-03
#
#      job_type salary_source  ... company_num_employees       company_revenue  \
# 0    fulltime   direct_data  ...        1,001 to 5,000    $500M to $1B (USD)
# 1  internship           NaN  ...               10,000+  more than $10B (USD)
# 2  internship           NaN  ...               10,000+  more than $10B (USD)
# 3  internship           NaN  ...               10,000+  more than $10B (USD)
# 4  internship           NaN  ...                   NaN                   NaN
#
#                                  company_description skills  experience_range  \
# 0                                                NaN   None              None
# 1  Synonymous with quality entertainment and cutt...   None              None
# 2  Synonymous with quality entertainment and cutt...   None              None
# 3  Synonymous with quality entertainment and cutt...   None              None
# 4                                                NaN   None              None
#
#   company_rating company_reviews_count vacancy_count work_from_home_type  \
# 0           None                  None          None                None
# 1           None                  None          None                None
# 2           None                  None          None                None
# 3           None                  None          None                None
# 4           None                  None          None                None
#
#                search_term
# 0  computer science intern
# 1  computer science intern
# 2  computer science intern
# 3  computer science intern
# 4  computer science intern
#
# [5 rows x 35 columns]

# %%
raw_df.value_counts("title")
# Out:
# title
# Software Engineer Intern                                        35
# Robotics - Software Development Engineer Intern/Co-op - 2026    23
# Software Engineering Intern                                     19
# Software Engineering Internship - Summer 2026                   18
# Data Scientist                                                  16
#                                                                 ..
# Industrial AI Internship                                         1
# IT Systems Analyst Intern - Summer 2026                          1
# IT Software Development Intern                                   1
# IT Service Delivery Manager                                      1
# iOS Intern                                                       1
# Name: count, Length: 631, dtype: int64

# %%
df = raw_df.copy()

# Create a combined text field to search for OPT-related keywords
description_col = "description" if "description" in df.columns else None
snippet_col = "snippet" if "snippet" in df.columns else None

# Start with the title, filling any NaN values with an empty string
combined_text_series = df["title"].fillna("").astype(str)

# Concatenate description if available
if description_col and not df[description_col].isnull().all(): # Check if column exists and is not entirely null
    combined_text_series = combined_text_series.str.cat(df[description_col].fillna("").astype(str), sep=" ")

# Concatenate snippet if available
if snippet_col and not df[snippet_col].isnull().all(): # Check if column exists and is not entirely null
    combined_text_series = combined_text_series.str.cat(df[snippet_col].fillna("").astype(str), sep=" ")

df["search_text"] = combined_text_series.str.lower()

# Filter for internships explicitly (job title contains "intern" or "co-op")
intern_mask = df["title"].str.lower().str.contains("intern|co-op|co op", na=False)

df_interns = df[intern_mask].copy()
print(f"Internship-like roles: {len(df_interns)}")

df_interns[["title", "company", "location", "site"]].head(10)
# Out:
# Internship-like roles: 879
#                                                title  \
# 0  Energy Supply Student Internship: Fusion Stude...
# 1                   Data Product Intern, Summer 2026
# 2           Software Engineering Intern, Summer 2026
# 3           Software Engineering Intern, Summer 2026
# 4                  Intern, Internal Audit Technology
# 5  AI Assisted Software Developer (Intern / Entry...
# 6  AI Assisted Software Developer (Intern / Entry...
# 7                             PLC Programming intern
# 8                              IT Integration Intern
# 9                                 AI Engineer Intern
#
#                              company                  location    site
# 0  Electric Power Research Institute         Charlotte, NC, US  indeed
# 1            The Walt Disney Company          Bay Lake, FL, US  indeed
# 2            The Walt Disney Company           Orlando, FL, US  indeed
# 3            The Walt Disney Company  Lake Buena Vista, FL, US  indeed
# 4                        Hf Sinclair            Dallas, TX, US  indeed
# 5                            Maxus33                        US  indeed
# 6                            Maxus33                Remote, US  indeed
# 7                 Schneider Electric           Raleigh, NC, US  indeed
# 8                 Schneider Electric           Raleigh, NC, US  indeed
# 9                Promega Corporation           Madison, WI, US  indeed

# %%
# Apply positive and negative keyword filters on search_text
good_mask = df_interns["search_text"].apply(lambda t: contains_any(t, GOOD_KEYWORDS))
bad_mask = df_interns["search_text"].apply(lambda t: contains_any(t, BAD_KEYWORDS))

df_opt = df_interns[good_mask & ~bad_mask].copy()
print(f"Potential OPT-friendly internships: {len(df_opt)}")

# Add an 'opt_score' column for simple ranking
df_opt["opt_score"] = df_opt["search_text"].apply(
    lambda t: score_text(t, GOOD_KEYWORDS, BAD_KEYWORDS)
)

# Select useful columns if they exist
columns_to_keep = []
for col in ["title", "company", "location", "site", "search_term", "url", "description", "snippet", "opt_score"]:
    if col in df_opt.columns:
        columns_to_keep.append(col)

df_opt = df_opt[columns_to_keep]

# Sort by opt_score descending
df_opt = df_opt.sort_values("opt_score", ascending=False)

df_opt.head(20)
# Out:
# Potential OPT-friendly internships: 180
#                                                  title              company  \
# 277  2026 Operations Research Science Internship - ...           Amazon.com
# 276  2026 Operations Research Science Internship - ...           Amazon.com
# 149  2026 Operations Research Science Internship - ...           Amazon.com
# 148  2026 Operations Research Science Internship - ...           Amazon.com
# 516  2026 Operations Research Science Internship - ...           Amazon.com
# 519  2026 Operations Research Science Internship - ...           Amazon.com
# 257  Internship, Automation Development & Tooling E...                Tesla
# 71                                         RFIC Intern                Nokia
# 63   Internship, Controls Engineer, Manufacturing (...                Tesla
# 62   Internship, Automation Development & Tooling E...                Tesla
# 157  Internship, Automotive Photographer, Design St...                Tesla
# 279  Research Scientist Intern, Center for Quantum ...  Amazon Web Services
# 278  Research Scientist Intern, Center for Quantum ...  Amazon Web Services
# 384  2026 Summer Intern - Software Engineer, Machin...       General Motors
# 201  Laser Department Manufacturing Intern (Spring ...                  NaN
# 359     Web & Mobile App Developer (Remote Internship)         bbcmgtAI LLC
# 522  Fulfillment Workplace Health and Safety Specia...           Amazon.com
# 523  Fulfillment Workplace Health and Safety Specia...           Amazon.com
# 524  Fulfillment Workplace Health and Safety Specia...           Amazon.com
# 67                       Network Systems Summer Intern                Nokia
#
#                   location    site                search_term  \
# 277        Seattle, WA, US  indeed   software engineer intern
# 276      Corvallis, OR, US  indeed   software engineer intern
# 149        Seattle, WA, US  indeed    computer science intern
# 148      Corvallis, OR, US  indeed    computer science intern
# 516      Corvallis, OR, US  indeed        data science intern
# 519        Seattle, WA, US  indeed        data science intern
# 257  Brooklyn Park, MN, US  indeed   software engineer intern
# 71                      US  indeed    computer science intern
# 63         Fremont, CA, US  indeed    computer science intern
# 62   Brooklyn Park, MN, US  indeed    computer science intern
# 157        Fremont, CA, US  indeed   software engineer intern
# 279       Pasadena, CA, US  indeed   software engineer intern
# 278    Santa Clara, CA, US  indeed   software engineer intern
# 384  Mountain View, CA, US  indeed  software developer intern
# 201       Seabrook, NH, US  indeed   software engineer intern
# 359             Remote, US  indeed  software developer intern
# 522      Riverside, CA, US  indeed        data science intern
# 523       Thornton, CO, US  indeed        data science intern
# 524         Dallas, TX, US  indeed        data science intern
# 67                      US  indeed    computer science intern
#
#                                            description  opt_score
# 277  **DESCRIPTION**\n---------------\n\n\nDo you e...          6
# 276  **DESCRIPTION**\n---------------\n\n\nDo you e...          6
# 149  **DESCRIPTION**\n---------------\n\n\nDo you e...          6
# 148  **DESCRIPTION**\n---------------\n\n\nDo you e...          6
# 516  **DESCRIPTION**\n---------------\n\n\nDo you e...          6
# 519  **DESCRIPTION**\n---------------\n\n\nDo you e...          6
# 257  **What to Expect**\nConsider before submitting...          5
# 71   **Number of Position(s):** 1  \n\n  \n\n**Dura...          5
# 63   **What to Expect**\nConsider before submitting...          5
# 62   **What to Expect**\nConsider before submitting...          5
# 157  **What to Expect**\nConsider before submitting...          5
# 279  **DESCRIPTION**\n---------------\n\n\nThe Amaz...          4
# 278  **DESCRIPTION**\n---------------\n\n\nThe Amaz...          4
# 384  **Job Description**\n\nGM does not provide imm...          4
# 201  **Key Responsibilities:**\n\n\n* **Laser Progr...          4
# 359  **Web \& Mobile App Developer (Remote Internsh...          3
# 522  **DESCRIPTION**\n---------------\n\n\nApplicat...          3
# 523  **DESCRIPTION**\n---------------\n\n\nApplicat...          3
# 524  **DESCRIPTION**\n---------------\n\n\nApplicat...          3
# 67   Number of Position(s): 2\n  \n\nDuration: 10 w...          3

# %%
# Deduplicate based on title + company + location + site
dedupe_keys = [c for c in ["title", "company", "location", "site"] if c in df_opt.columns]
df_opt_unique = df_opt.drop_duplicates(subset=dedupe_keys, keep="first").reset_index(drop=True)

print(f"After deduplication: {len(df_opt_unique)} internships\n")

# Show a preview
df_opt_unique.head(20)
# Out:
# After deduplication: 131 internships
#                                                 title              company  \
# 0   2026 Operations Research Science Internship - ...           Amazon.com
# 1   2026 Operations Research Science Internship - ...           Amazon.com
# 2   Internship, Automation Development & Tooling E...                Tesla
# 3                                         RFIC Intern                Nokia
# 4   Internship, Controls Engineer, Manufacturing (...                Tesla
# 5   Internship, Automotive Photographer, Design St...                Tesla
# 6   Research Scientist Intern, Center for Quantum ...  Amazon Web Services
# 7   Research Scientist Intern, Center for Quantum ...  Amazon Web Services
# 8   2026 Summer Intern - Software Engineer, Machin...       General Motors
# 9   Laser Department Manufacturing Intern (Spring ...                  NaN
# 10     Web & Mobile App Developer (Remote Internship)         bbcmgtAI LLC
# 11  Fulfillment Workplace Health and Safety Specia...           Amazon.com
# 12  Fulfillment Workplace Health and Safety Specia...           Amazon.com
# 13  Fulfillment Workplace Health and Safety Specia...           Amazon.com
# 14                      Network Systems Summer Intern                Nokia
# 15  Fulfillment Workplace Health and Safety Specia...           Amazon.com
# 16  Fulfillment Workplace Health and Safety Specia...           Amazon.com
# 17  2026 Summer Internship: Sales Administration -...               PACCAR
# 18  Fulfillment Workplace Health and Safety Specia...           Amazon.com
# 19  Fulfillment Workplace Health and Safety Specia...           Amazon.com
#
#                  location    site                search_term  \
# 0         Seattle, WA, US  indeed   software engineer intern
# 1       Corvallis, OR, US  indeed   software engineer intern
# 2   Brooklyn Park, MN, US  indeed   software engineer intern
# 3                      US  indeed    computer science intern
# 4         Fremont, CA, US  indeed    computer science intern
# 5         Fremont, CA, US  indeed   software engineer intern
# 6        Pasadena, CA, US  indeed   software engineer intern
# 7     Santa Clara, CA, US  indeed   software engineer intern
# 8   Mountain View, CA, US  indeed  software developer intern
# 9        Seabrook, NH, US  indeed   software engineer intern
# 10             Remote, US  indeed  software developer intern
# 11      Riverside, CA, US  indeed        data science intern
# 12       Thornton, CO, US  indeed        data science intern
# 13         Dallas, TX, US  indeed        data science intern
# 14                     US  indeed    computer science intern
# 15         DuPont, WA, US  indeed        data science intern
# 16    West Jordan, UT, US  indeed        data science intern
# 17         Denton, TX, US  indeed    computer science intern
# 18     Fort Worth, TX, US  indeed        data science intern
# 19  Oklahoma City, OK, US  indeed        data science intern
#
#                                           description  opt_score
# 0   **DESCRIPTION**\n---------------\n\n\nDo you e...          6
# 1   **DESCRIPTION**\n---------------\n\n\nDo you e...          6
# 2   **What to Expect**\nConsider before submitting...          5
# 3   **Number of Position(s):** 1  \n\n  \n\n**Dura...          5
# 4   **What to Expect**\nConsider before submitting...          5
# 5   **What to Expect**\nConsider before submitting...          5
# 6   **DESCRIPTION**\n---------------\n\n\nThe Amaz...          4
# 7   **DESCRIPTION**\n---------------\n\n\nThe Amaz...          4
# 8   **Job Description**\n\nGM does not provide imm...          4
# 9   **Key Responsibilities:**\n\n\n* **Laser Progr...          4
# 10  **Web \& Mobile App Developer (Remote Internsh...          3
# 11  **DESCRIPTION**\n---------------\n\n\nApplicat...          3
# 12  **DESCRIPTION**\n---------------\n\n\nApplicat...          3
# 13  **DESCRIPTION**\n---------------\n\n\nApplicat...          3
# 14  Number of Position(s): 2\n  \n\nDuration: 10 w...          3
# 15  **DESCRIPTION**\n---------------\n\n\nApplicat...          3
# 16  **DESCRIPTION**\n---------------\n\n\nApplicat...          3
# 17  **Company Information**\n---------------------...          3
# 18  **DESCRIPTION**\n---------------\n\n\nApplicat...          3
# 19  **DESCRIPTION**\n---------------\n\n\nApplicat...          3

# %%
# Save to CSV
output_path = "opt_internships.csv"
df_opt_unique.to_csv(output_path, index=False)
print(f"Saved {len(df_opt_unique)} internships to: {output_path}")
# Out:
# Saved 131 internships to: opt_internships.csv

# %%
print("=== Summary ===")
print(f"Total raw jobs scraped: {len(raw_df)}")
print(f"Internship-like roles: {len(df_interns)}")
print(f"Potential OPT-friendly (before dedupe): {len(df_opt)}")
print(f"Unique OPT-like internships (after dedupe): {len(df_opt_unique)}")

print("\nSample of results:")
df_opt_unique[["title", "company", "location", "site", "opt_score"]].head(10)
# Out:
# === Summary ===
# Total raw jobs scraped: 1070
# Internship-like roles: 879
# Potential OPT-friendly (before dedupe): 180
# Unique OPT-like internships (after dedupe): 131
#
# Sample of results:
#                                                title              company  \
# 0  2026 Operations Research Science Internship - ...           Amazon.com
# 1  2026 Operations Research Science Internship - ...           Amazon.com
# 2  Internship, Automation Development & Tooling E...                Tesla
# 3                                        RFIC Intern                Nokia
# 4  Internship, Controls Engineer, Manufacturing (...                Tesla
# 5  Internship, Automotive Photographer, Design St...                Tesla
# 6  Research Scientist Intern, Center for Quantum ...  Amazon Web Services
# 7  Research Scientist Intern, Center for Quantum ...  Amazon Web Services
# 8  2026 Summer Intern - Software Engineer, Machin...       General Motors
# 9  Laser Department Manufacturing Intern (Spring ...                  NaN
#
#                 location    site  opt_score
# 0        Seattle, WA, US  indeed          6
# 1      Corvallis, OR, US  indeed          6
# 2  Brooklyn Park, MN, US  indeed          5
# 3                     US  indeed          5
# 4        Fremont, CA, US  indeed          5
# 5        Fremont, CA, US  indeed          5
# 6       Pasadena, CA, US  indeed          4
# 7    Santa Clara, CA, US  indeed          4
# 8  Mountain View, CA, US  indeed          4
# 9       Seabrook, NH, US  indeed          4
